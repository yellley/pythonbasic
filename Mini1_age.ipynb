# %%
import pandas as pd
import numpy as np

#%%
import matplotlib.font_manager as font_manager
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


#폰트
font_dir = ['C:/mini_1/ye/fonts'] 
for font in font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname = font).get_name()) #이름확인
    font_manager.fontManager.addfont(font) #추가

    
# Set font family globally
mpl.rcParams['font.family'] = 'Gothic A1'
print(mpl.rcParams['font.family'])





#파일 불러오기
age = pd.read_csv("Tax/age.csv", encoding='euc-kr')
age
# Out:
# Gothic A1
# ['Gothic A1']
#         업종명                                      영문명  30세 미만  30세 이상  40세 이상  \
# 0       가구점                           Furniture Shop     102     197     276
# 1   가전제품수리점               Home Appliance Repair Shop     396    1145    1352
# 2   가전제품판매점               Electrical Appliances Shop      75     207     305
# 3      간이주점                                      Pub     256     425     413
# 4    간판광고물업  Manufacture of Signs and Advertisements      43     103     190
# ..      ...                                      ...     ...     ...     ...
# 95    호프전문점                                 Beer Bar     752    1240    1570
# 96    화장품가게                           Cosmetics Shop    1036    1964    2125
# 97    휴대폰가게                        Mobile Phone Shop    1198    1781     792
# 98  LPG 충전소                              LPG Station       8      14      25
# 99      pc방                                  PC Room     249     725     884
#
#     50세 이상  60세 이상
# 0      230      96
# 1      718     245
# 2      254     112
# 3      455     185
# 4      122      38
# ..     ...     ...
# 95    1467     571
# 96    1570     773
# 97     364     199
# 98      88      21
# 99     615     246
#
# [100 rows x 7 columns]

# %%
#복사본
age_c = age.copy()
age_c
# Out:
#         업종명                                      영문명  30세 미만  30세 이상  40세 이상  \
# 0       가구점                           Furniture Shop     102     197     276
# 1   가전제품수리점               Home Appliance Repair Shop     396    1145    1352
# 2   가전제품판매점               Electrical Appliances Shop      75     207     305
# 3      간이주점                                      Pub     256     425     413
# 4    간판광고물업  Manufacture of Signs and Advertisements      43     103     190
# ..      ...                                      ...     ...     ...     ...
# 95    호프전문점                                 Beer Bar     752    1240    1570
# 96    화장품가게                           Cosmetics Shop    1036    1964    2125
# 97    휴대폰가게                        Mobile Phone Shop    1198    1781     792
# 98  LPG 충전소                              LPG Station       8      14      25
# 99      pc방                                  PC Room     249     725     884
#
#     50세 이상  60세 이상
# 0      230      96
# 1      718     245
# 2      254     112
# 3      455     185
# 4      122      38
# ..     ...     ...
# 95    1467     571
# 96    1570     773
# 97     364     199
# 98      88      21
# 99     615     246
#
# [100 rows x 7 columns]

# %%
#칼럼, 로우 확인
print(age_c.columns)
print(age_c.index)
# Out:
# Index(['업종명', '영문명', '30세 미만', '30세 이상', '40세 이상', '50세 이상', '60세 이상'], dtype='object')
# RangeIndex(start=0, stop=100, step=1)

# %%
#인덱스 업종명으로 바꾸기
age_c.set_index('업종명 ', drop=True, inplace = True)
age_c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21488\3798875769.py in <module>
#       1 #인덱스 업종명으로 바꾸기
# ----> 2 age_c.set_index('업종명 ', drop=True, inplace = True)
#       3 age_c
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['업종명 '] are in the columns"

# %%
age_c
# Out:
#                                              영문명  30세 미만  30세 이상  40세 이상  \
# 업종명
# 가구점                               Furniture Shop     102     197     276
# 가전제품수리점               Home Appliance Repair Shop     396    1145    1352
# 가전제품판매점               Electrical Appliances Shop      75     207     305
# 간이주점                                         Pub     256     425     413
# 간판광고물업   Manufacture of Signs and Advertisements      43     103     190
# ...                                          ...     ...     ...     ...
# 호프전문점                                   Beer Bar     752    1240    1570
# 화장품가게                             Cosmetics Shop    1036    1964    2125
# 휴대폰가게                          Mobile Phone Shop    1198    1781     792
# LPG 충전소                              LPG Station       8      14      25
# pc방                                      PC Room     249     725     884
#
#          50세 이상  60세 이상
# 업종명
# 가구점         230      96
# 가전제품수리점     718     245
# 가전제품판매점     254     112
# 간이주점        455     185
# 간판광고물업      122      38
# ...         ...     ...
# 호프전문점      1467     571
# 화장품가게      1570     773
# 휴대폰가게       364     199
# LPG 충전소      88      21
# pc방         615     246
#
# [100 rows x 6 columns]

# %%
age_c.drop('영문명', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21488\3250162304.py in <module>
# ----> 1 age_c.drop('영문명', axis = 1, inplace = True)
#       2 age_c
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['영문명'] not found in axis"

# %%
age_c
# Out:
#          30세 미만  30세 이상  40세 이상  50세 이상  60세 이상
# 업종명
# 가구점         102     197     276     230      96
# 가전제품수리점     396    1145    1352     718     245
# 가전제품판매점      75     207     305     254     112
# 간이주점        256     425     413     455     185
# 간판광고물업       43     103     190     122      38
# ...         ...     ...     ...     ...     ...
# 호프전문점       752    1240    1570    1467     571
# 화장품가게      1036    1964    2125    1570     773
# 휴대폰가게      1198    1781     792     364     199
# LPG 충전소       8      14      25      88      21
# pc방         249     725     884     615     246
#
# [100 rows x 5 columns]

# %%
# age_c["30세 미만"]

# colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red']
# labels = ['Man', 'Woman', 'Prefer not to say', 'Non-binary, genderqueer, or gender non-conforming', 'Or, in your own words:']


# plt.title("Which of the following describe you, if any? Please check all that apply")
# plt.pie(count_g, labels = labels, colors = colors, autopct = '%1.1f%%', startangle = 180)
# plt.axis('equal')
# plt.show()
# Out:
# 업종명
# 가구점         102
# 가전제품수리점     396
# 가전제품판매점      75
# 간이주점        256
# 간판광고물업       43
#            ...
# 호프전문점       752
# 화장품가게      1036
# 휴대폰가게      1198
# LPG 충전소       8
# pc방         249
# Name: 30세 미만, Length: 100, dtype: int64

# %%
age_c = age_c.T

# %%
age_c
# Out:
# 업종명     가구점  가전제품수리점  가전제품판매점  간이주점  간판광고물업  감정평가사  건강보조식품가게  건어물가게  건축사  \
# 30세 미만  102      396       75   256      43      0       200     77    5
# 30세 이상  197     1145      207   425     103     18       474    161  260
# 40세 이상  276     1352      305   413     190     60       700    271  456
# 50세 이상  230      718      254   455     122     25       692    301  210
# 60세 이상   96      245      112   185      38     34       480    296   69
#
# 업종명     결혼상담소  ...  피부관리업  피부ㆍ비뇨기과 의원  한방병원ㆍ한의원  한식전문점  헬스클럽  호프전문점  화장품가게  \
# 30세 미만     33  ...   2559           5        55  10388   386    752   1036
# 30세 이상     67  ...   3536         180       416  17860   878   1240   1964
# 40세 이상    104  ...   2122         100       238  20568   375   1570   2125
# 50세 이상     95  ...    984          38       165  19787   111   1467   1570
# 60세 이상     80  ...    292          19        48  10718    71    571    773
#
# 업종명     휴대폰가게  LPG 충전소  pc방
# 30세 미만   1198        8  249
# 30세 이상   1781       14  725
# 40세 이상    792       25  884
# 50세 이상    364       88  615
# 60세 이상    199       21  246
#
# [5 rows x 100 columns]

# %%
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red']
# labels = ['Man', 'Woman', 'Prefer not to say', 'Non-binary, genderqueer, or gender non-conforming', 'Or, in your own words:']


plt.title("Which of the following describe you, if any? Please check all that apply")
# plt.pie(count_g, labels = labels, colors = colors, autopct = '%1.1f%%', startangle = 180)
# plt.axis('equal')
# plt.show()
